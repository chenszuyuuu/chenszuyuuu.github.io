# %%
import pandas as pd

# %%
df = pd.read_csv("globalterrorismdb_0718dist.csv", encoding = "ISO-8859-1")

# %%
df.head()
# Out:
#         eventid  iyear  imonth  iday approxdate  extended resolution  country  \
# 0  197000000001   1970       7     2        NaN         0        NaN       58
# 1  197000000002   1970       0     0        NaN         0        NaN      130
# 2  197001000001   1970       1     0        NaN         0        NaN      160
# 3  197001000002   1970       1     0        NaN         0        NaN       78
# 4  197001000003   1970       1     0        NaN         0        NaN      101
#
#           country_txt  region  ... addnotes scite1 scite2  scite3  dbsource  \
# 0  Dominican Republic       2  ...      NaN    NaN    NaN     NaN      PGIS
# 1              Mexico       1  ...      NaN    NaN    NaN     NaN      PGIS
# 2         Philippines       5  ...      NaN    NaN    NaN     NaN      PGIS
# 3              Greece       8  ...      NaN    NaN    NaN     NaN      PGIS
# 4               Japan       4  ...      NaN    NaN    NaN     NaN      PGIS
#
# ...

# %%
us = df[df["country"]==217]
us.head()
# Out:
#          eventid  iyear  imonth  iday approxdate  extended resolution  \
# 5   197001010002   1970       1     1        NaN         0        NaN
# 7   197001020002   1970       1     2        NaN         0        NaN
# 8   197001020003   1970       1     2        NaN         0        NaN
# 9   197001030001   1970       1     3        NaN         0        NaN
# 10  197001050001   1970       1     1        NaN         0        NaN
#
#     country    country_txt  region  ...  \
# 5       217  United States       1  ...
# 7       217  United States       1  ...
# 8       217  United States       1  ...
# 9       217  United States       1  ...
# 10      217  United States       1  ...
#
#                                              addnotes  \
# 5   The Cairo Chief of Police, William Petersen, r...
# 7   Damages were estimated to be between $20,000-$...
# 8   The New Years Gang issue a communiqué to a loc...
# 9   Karl Armstrong's girlfriend, Lynn Schultz, dro...
# ...

# %%
us = us[["eventid", "iyear", "imonth", "iday", "nkill","country", "country_txt", "provstate", "city", "success", "gname", "weaptype1", "weaptype1_txt", "weapdetail"]]

# %%
us = us.reset_index(drop=True)

# %%
us.isnull().sum()
# Out:
# eventid            0
# iyear              0
# imonth             0
# iday               0
# nkill             73
# country            0
# country_txt        0
# provstate          4
# city               0
# success            0
# gname              0
# weaptype1          0
# weaptype1_txt      0
# weapdetail       544
# dtype: int64

# %%
us.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2836 entries, 0 to 2835
# Data columns (total 14 columns):
# eventid          2836 non-null int64
# iyear            2836 non-null int64
# imonth           2836 non-null int64
# iday             2836 non-null int64
# nkill            2763 non-null float64
# country          2836 non-null int64
# country_txt      2836 non-null object
# provstate        2832 non-null object
# city             2836 non-null object
# success          2836 non-null int64
# gname            2836 non-null object
# weaptype1        2836 non-null int64
# weaptype1_txt    2836 non-null object
# weapdetail       2292 non-null object
# dtypes: float64(1), int64(7), object(6)
# memory usage: 310.3+ KB

# %%
us.head()
# Out:
#         eventid  iyear  imonth  iday  nkill  country    country_txt  \
# 0  197001010002   1970       1     1    0.0      217  United States
# 1  197001020002   1970       1     2    0.0      217  United States
# 2  197001020003   1970       1     2    0.0      217  United States
# 3  197001030001   1970       1     3    0.0      217  United States
# 4  197001050001   1970       1     1    0.0      217  United States
#
#     provstate     city  success                            gname  weaptype1  \
# 0    Illinois    Cairo        1               Black Nationalists          5
# 1  California  Oakland        1                          Unknown          6
# 2   Wisconsin  Madison        1                  New Year's Gang          8
# 3   Wisconsin  Madison        1                  New Year's Gang          8
# 4   Wisconsin  Baraboo        0  Weather Underground, Weathermen          6
#
#   weaptype1_txt
# 0      Firearms
# 1    Explosives
# 2    Incendiary
# 3    Incendiary
# ...

# %%
us.nkill.isnull().sum()
# Out:
# 73

# %%
groupby = us[["eventid", "iyear"]].groupby(["iyear"]).count()
groupby.to_csv("terr_year.csv")

# %%
groupby[groupby["iyear"]==1993]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# /opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_loc(self, key, method, tolerance)
#    2896             try:
# -> 2897                 return self._engine.get_loc(key)
#    2898             except KeyError:
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'iyear'
#
# During handling of the above exception, another exception occurred:
#
# KeyError                                  Traceback (most recent call last)
# <ipython-input-170-285ee402b690> in <module>
# ----> 1 groupby[groupby["iyear"]==1993]
#
# ...

# %%
index_l = []
year_l = []
month_l = []
day_l = []
kill_l = []
state_l = []
city_l = []
success_l = []
terr_l = []
weap_l = []
weapdetail_l = []
for i in range(len(us)):
    index = int(i)
    year = int(us["iyear"][i])
    month = int(us["imonth"][i])
    day = int(us["iday"][i])
    if pd.isna(us["nkill"][i])==True:
        kill = "null"
    else:
        kill = int(us["nkill"][i])
    if pd.isna(us["weapdetail"][i])==True:
        weapdetail = "null"
    else:
        weapdetail = us["weapdetail"][i]
    if pd.isna(us["provstate"][i]) == True:
        state = "null"
    else: 
        state = us["provstate"][i]
    city = us["city"][i]
    success = int(us["success"][i])
    terr_group = us["gname"][i]
    weaptype = us["weaptype1_txt"][i]
    
    index_l.append(index)
    year_l.append(year)
    month_l.append(month)
    day_l.append(day)
    kill_l.append(kill)
    success_l.append(success)
    state_l.append(state)
    city_l.append(city)
    terr_l.append(terr_group)
    weap_l.append(weaptype)
    weapdetail_l.append(weapdetail)

# %%
index_l.append(-1)
year_l.append(1993)
month_l.append("null")
day_l.append("null")
kill_l.append("null")
success_l.append("null")
state_l.append("null")
city_l.append("null")
terr_l.append("null")
weap_l.append("null")
weapdetail_l.append("null")

# %%
dic = {
    "index": index_l,
    "year": year_l,
    "month": month_l,
    "day": day_l,
    "success_or_not": success_l,
    "state": state_l,
    "city": city_l,
    "kill": kill_l,
    "terr_group": terr_l,
    "weapon": weap_l,
    "weapdetail": weapdetail_l
}
dic = pd.DataFrame.from_dict(dic)

# %%
dic.tail()
# Out:
#       index  year month   day success_or_not         state           city  \
# 2832   2832  2017    12     7              1    New Mexico          Aztec
# 2833   2833  2017    12    11              1      New York  New York City
# 2834   2834  2017    12    22              1  Pennsylvania     Harrisburg
# 2835   2835  2017    12    22              1  Pennsylvania     Harrisburg
# 2836     -1  1993  null  null           null          null           null
#
#       kill                  terr_group      weapon  \
# 2832     3            White extremists    Firearms
# 2833     0  Jihadi-inspired extremists  Explosives
# 2834     0                     Unknown    Firearms
# 2835     1                     Unknown    Firearms
# 2836  null                        null        null
#
#                                              weapdetail
# 2832       A 9-mm Glock handgun was used in the attack.
# 2833  A crude pipe bomb consisting of screws,  Chris...
# ...

# %%
import json

json = dic.to_json(orient='records')
with open('terr.json', 'w') as f:
    f.write(json)
